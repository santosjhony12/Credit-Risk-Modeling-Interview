# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
df = pd.read_excel('../data/processed/train_processed.xlsx')

# %%
df.head(5)
# Out:
#            V1   V3  V4           V5       V6          V7       V8       V9  \
# 0  563.101990   12   6  1264.109985  1.67665  944.123108  0.03750  0.19642
# 1  283.477509   15   2   408.279999  1.12000  317.494812  0.02437  0.13218
# 2  492.380005  365   1     0.000000  0.00000    0.000000  0.02437  0.00706
# 3   92.010002  365   0     0.000000  0.00000    0.000000  0.00000  0.00400
# 4  235.660004  365   0     0.000000  0.00000    0.000000  0.02437 -0.02804
#
#    V10  V11  ...  V14_Ocasional  V17_Ativo  V17_Ausente  V17_Basico  \
# 0   10  353  ...              0          0            0           0
# 1   72  173  ...              1          0            0           0
# 2   65  318  ...              0          0            0           0
# 3   92  332  ...              0          0            0           0
# 4   92  157  ...              0          0            0           0
#
#    V17_Conveniencia  V17_Economico  V17_Inativo  V17_Novo  V17_Premium  \
# ...

# %%
df.isnull().sum()
# Out:
# V1                            0
# V3                            0
# V4                            0
# V5                            0
# V6                            0
# V7                            0
# V8                            0
# V9                            0
# V10                           0
# V11                           0
# V15                           0
# V16                           0
# V18                           0
# V19                           0
# V2_B                          0
# V2_G                          0
# V2_M                          0
# V2_W                          0
# V12_Ausente                   0
# V12_Fiel                      0
# V12_Inativo                   0
# V12_Novo                      0
# V12_Ocasional                 0
# V13_Ausente                   0
# V13_Fiel                      0
# V13_Inativo                   0
# V13_Novo                      0
# V13_Ocasional                 0
# V14_Ausente                   0
# ...

# %%
X = df.drop('PERFORMANCE (var resposta)', axis=1)

y = df['PERFORMANCE (var resposta)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14996, 41), (3749, 41), (14996,), (3749,))

# %%
print(y_train.value_counts(normalize=True)*100)

print(y_test.value_counts(normalize=True)*100)
# Out:
# PERFORMANCE (var resposta)
# 0    80.054681
# 1    19.945319
# Name: proportion, dtype: float64
# PERFORMANCE (var resposta)
# 0    80.048013
# 1    19.951987
# Name: proportion, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced"
)

rf.fit(X, y)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300, n_jobs=-1,
#                        random_state=42)

# %%
importance = pd.DataFrame({
    "Variavel": X.columns,
    "Importancia": rf.feature_importances_
})

importance = importance.sort_values(
    "Importancia",
    ascending=False
)

importance
# Out:
#             Variavel  Importancia
# 13               V19     0.139049
# 0                 V1     0.119368
# 9                V11     0.108883
# 7                 V9     0.107119
# 6                 V8     0.057757
# 8                V10     0.056241
# 3                 V5     0.047965
# 5                 V7     0.047941
# 12               V18     0.046048
# 4                 V6     0.045167
# 2                 V4     0.036316
# 10               V15     0.025242
# 1                 V3     0.023094
# 40       V17_Premium     0.011182
# 16              V2_M     0.009429
# 14              V2_B     0.008845
# 15              V2_G     0.008413
# 30       V14_Inativo     0.007799
# 28       V14_Ausente     0.007693
# 29          V14_Fiel     0.007246
# 32     V14_Ocasional     0.006637
# 38       V17_Inativo     0.006622
# 17              V2_W     0.006574
# 11               V16     0.006340
# 25       V13_Inativo     0.005873
# 20       V12_Inativo     0.005367
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))

sns.barplot(
    data=importance.head(20),
    x="Importancia",
    y="Variavel"
)

plt.title("Importância das Variáveis - Random Forest")
plt.xlabel("Importância")
plt.ylabel("Variável")

plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
df_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
df_scaled.head()
# Out:
#          V1        V3        V4        V5        V6        V7        V8  \
# 0 -0.757490 -1.631192 -0.488834 -0.685569 -0.733304 -0.701836 -0.244196
# 1 -0.483957  0.620411  1.040404  0.316454  0.555864  0.165779 -0.244196
# 2  0.029712  0.620411  1.652100  1.911522  1.693364  2.532755 -0.264977
# 3 -0.347081 -1.676744  1.957947  1.630121  1.183593  0.925332  2.801406
# 4 -0.679001  0.620411  0.581633  0.191359  1.001446  0.030963 -0.244196
#
#          V9       V10       V11  ...  V14_Novo  V14_Ocasional  V17_Ativo  \
# 0  0.347454  0.274654 -1.708258  ... -0.185913      -0.325673  -0.268729
# 1 -1.136924 -0.979204 -0.647849  ... -0.185913      -0.325673  -0.268729
# 2 -0.864991 -1.059238  0.777077  ... -0.185913      -0.325673  -0.268729
# 3  1.964947 -1.112593  0.346286  ... -0.185913      -0.325673  -0.268729
# 4 -1.251338 -0.712426  1.183016  ... -0.185913      -0.325673  -0.268729
#
#    V17_Ausente  V17_Basico  V17_Conveniencia  V17_Economico  V17_Inativo  \
# ...

# %%
df_scaled.describe()
# Out:
#                  V1            V3            V4            V5            V6  \
# count  1.499600e+04  1.499600e+04  1.499600e+04  1.499600e+04  1.499600e+04
# mean  -8.623551e-17  9.476430e-18 -3.506279e-17  3.743190e-17 -6.467664e-17
# std    1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00  1.000033e+00
# min   -1.003715e+00 -1.748327e+00 -6.417581e-01 -6.855692e-01 -7.333038e-01
# 25%   -6.690282e-01 -1.273278e+00 -6.417581e-01 -6.855692e-01 -7.333038e-01
# 50%   -3.087919e-01  6.204107e-01 -3.359104e-01 -2.615133e-01 -2.306185e-01
# 75%    3.432399e-01  6.204107e-01  1.228612e-01  3.724569e-01  2.377332e-01
# max    1.862171e+01  6.204107e-01  1.036876e+01  3.241046e+01  1.064170e+01
#
#                  V7            V8            V9           V10           V11  \
# count  1.499600e+04  1.499600e+04  1.499600e+04  1.499600e+04  1.499600e+04
# mean   7.296851e-17  5.875387e-17  2.748165e-17  7.344233e-17 -1.013978e-16
# ...

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
logistic = LogisticRegression(
    class_weight="balanced",
    max_iter=1000,
    random_state=42
)

logistic.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
xgb = XGBClassifier(
    n_estimators=300,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='binary:logistic',
    eval_metric='logloss',
    random_state=42,
    n_jobs=-1
)

xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
lgbm = LGBMClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

lgbm.fit(X_train, y_train)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.8,
#                learning_rate=0.05, n_estimators=300, n_jobs=-1, random_state=42,
#                subsample=0.8, verbosity=-1)

# %%
y_pred_logistic = logistic.predict(X_test_scaled)
y_prob_logistic = logistic.predict_proba(X_test_scaled)[:, 1]

# %%
y_pred_xgb = xgb.predict(X_test)
y_prob_xgb = xgb.predict_proba(X_test)[:, 1]

# %%
y_pred_lgbm = lgbm.predict(X_test)
y_prob_lgbm = lgbm.predict_proba(X_test)[:, 1]

# %%
models = {
    "Logistic Regression": y_pred_logistic,
    "XGBoost": y_pred_xgb,
    "LightGBM": y_pred_lgbm
}

probabilities = {
    "Logistic Regression": y_prob_logistic,
    "XGBoost": y_prob_xgb,
    "LightGBM": y_prob_lgbm
}

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

# %%
def evaluate_model(y_true, y_pred, y_prob):
    auc = roc_auc_score(y_true, y_prob)

    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1": f1_score(y_true, y_pred),
        "AUC": auc,
        "Gini": 2 * auc - 1
    }

# %%
results = []

for name in models:

    metrics = evaluate_model(
        y_test,
        models[name],
        probabilities[name]
    )

    metrics["Modelo"] = name

    results.append(metrics)

# %%
results_df = pd.DataFrame(results)

results_df = results_df[
    [
        "Modelo",
        "Accuracy",
        "Precision",
        "Recall",
        "F1",
        "AUC",
        "Gini"
    ]
]

results_df.sort_values(
    "AUC",
    ascending=False
)
# Out:
#                 Modelo  Accuracy  Precision    Recall        F1       AUC  \
# 1              XGBoost  0.803948   0.540373  0.116310  0.191419  0.715304
# 2             LightGBM  0.697786   0.348544  0.592246  0.438831  0.712553
# 0  Logistic Regression  0.649773   0.315721  0.647059  0.424375  0.711437
#
#        Gini
# 1  0.430609
# 2  0.425106
# 0  0.422873

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_lgbm
)

plt.title("Matriz de Confusão - LightGBM")
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_logistic
)

plt.title("Matriz de Confusão - Regressão Logística")
plt.show()

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test,
    y_pred_xgb
)

plt.title("Matriz de Confusão - XGBoost")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

for name, y_prob in probabilities.items():
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr,
        tpr,
        label=f"{name} (AUC = {roc_auc:.3f})"
    )

plt.plot(
    [0, 1],
    [0, 1],
    linestyle="--"
)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC - Comparação dos Modelos")
plt.legend()
plt.show()

# %%
import numpy as np

def calculate_ks(y_true, y_prob):
    data = pd.DataFrame({
        "y_true": y_true,
        "y_prob": y_prob
    })

    data = data.sort_values(
        "y_prob",
        ascending=False
    )

    data["bad"] = (data["y_true"] == 1).astype(int)
    data["good"] = (data["y_true"] == 0).astype(int)

    data["cum_bad"] = data["bad"].cumsum() / data["bad"].sum()
    data["cum_good"] = data["good"].cumsum() / data["good"].sum()

    data["ks"] = abs(
        data["cum_bad"] - data["cum_good"]
    )

    return data["ks"].max()

# %%
ks_results = {}

for name, y_prob in probabilities.items():
    ks_results[name] = calculate_ks(
        y_test,
        y_prob
    )

ks_results
# Out:
# {'Logistic Regression': np.float64(0.3092480759532919),
#  'XGBoost': np.float64(0.32294181796798566),
#  'LightGBM': np.float64(0.32301398642520235)}

# %%
results_df["KS"] = results_df["Modelo"].map(ks_results)

results_df = results_df[
    [
        "Modelo",
        "Accuracy",
        "Precision",
        "Recall",
        "F1",
        "AUC",
        "Gini",
        "KS"
    ]
]

results_df.sort_values(
    "AUC",
    ascending=False
)
# Out:
#                 Modelo  Accuracy  Precision    Recall        F1       AUC  \
# 1              XGBoost  0.803948   0.540373  0.116310  0.191419  0.715304
# 2             LightGBM  0.697786   0.348544  0.592246  0.438831  0.712553
# 0  Logistic Regression  0.649773   0.315721  0.647059  0.424375  0.711437
#
#        Gini        KS
# 1  0.430609  0.322942
# 2  0.425106  0.323014
# 0  0.422873  0.309248

# %%
feature_importance_lgbm = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": lgbm.feature_importances_
})

feature_importance_lgbm = feature_importance_lgbm.sort_values(
    "Importance",
    ascending=False
)

feature_importance_lgbm.head(20)
# Out:
#           Feature  Importance
# 0              V1        1048
# 9             V11        1042
# 7              V9         970
# 13            V19         928
# 12            V18         683
# 8             V10         661
# 3              V5         586
# 6              V8         551
# 4              V6         540
# 5              V7         522
# 2              V4         321
# 1              V3         201
# 10            V15         161
# 40    V17_Premium          74
# 14           V2_B          62
# 32  V14_Ocasional          48
# 15           V2_G          47
# 28    V14_Ausente          46
# 30    V14_Inativo          46
# 23    V13_Ausente          41

# %%
feature_importance_xgb = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": xgb.feature_importances_
})

feature_importance_xgb = feature_importance_xgb.sort_values(
    "Importance",
    ascending=False
)

feature_importance_xgb.head(20)
# Out:
#              Feature  Importance
# 40       V17_Premium    0.077102
# 25       V13_Inativo    0.069028
# 13               V19    0.052355
# 8                V10    0.041469
# 20       V12_Inativo    0.033458
# 2                 V4    0.030421
# 6                 V8    0.026121
# 38       V17_Inativo    0.025997
# 0                 V1    0.024249
# 5                 V7    0.024136
# 36  V17_Conveniencia    0.023966
# 37     V17_Economico    0.022905
# 9                V11    0.022783
# 7                 V9    0.022656
# 31          V14_Novo    0.022570
# 11               V16    0.021954
# 3                 V5    0.021776
# 29          V14_Fiel    0.021568
# 4                 V6    0.021218
# 17              V2_W    0.021175

# %%
from sklearn.inspection import permutation_importance

perm_lgbm = permutation_importance(
    lgbm,
    X_train,
    y_train,
    scoring="roc_auc",
    n_repeats=10,
    random_state=42,
    n_jobs=-1
)

# %%
permutation_lgbm = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance_Mean": perm_lgbm.importances_mean,
    "Importance_Std": perm_lgbm.importances_std
})

permutation_lgbm = permutation_lgbm.sort_values(
    "Importance_Mean",
    ascending=False
)

permutation_lgbm.head(20)
# Out:
#           Feature  Importance_Mean  Importance_Std
# 13            V19         0.124265        0.003554
# 0              V1         0.066286        0.001800
# 9             V11         0.055462        0.001655
# 7              V9         0.046326        0.001064
# 6              V8         0.043878        0.002105
# 8             V10         0.037890        0.001526
# 12            V18         0.033843        0.001077
# 4              V6         0.025906        0.000613
# 3              V5         0.025283        0.000631
# 5              V7         0.018045        0.000744
# 10            V15         0.014404        0.000723
# 1              V3         0.011268        0.000449
# 2              V4         0.010275        0.000416
# 14           V2_B         0.004047        0.000212
# 40    V17_Premium         0.003957        0.000529
# 37  V17_Economico         0.003206        0.000139
# 30    V14_Inativo         0.003031        0.000241
# ...

# %%
plt.figure(figsize=(10, 6))

plt.barh(
    permutation_lgbm["Feature"].head(15)[::-1],
    permutation_lgbm["Importance_Mean"].head(15)[::-1]
)

plt.xlabel("Queda média no ROC AUC")
plt.ylabel("Variável")
plt.title("Permutation Importance — LightGBM")

plt.tight_layout()
plt.show()

# %%
from sklearn.inspection import permutation_importance

perm_xgb = permutation_importance(
    xgb,
    X_train,
    y_train,
    scoring="roc_auc",
    n_repeats=10,
    random_state=42,
    n_jobs=-1
)

# %%
permutation_xgb = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance_Mean": perm_xgb.importances_mean,
    "Importance_Std": perm_xgb.importances_std
})

permutation_xgb = permutation_xgb.sort_values(
    "Importance_Mean",
    ascending=False
)

permutation_xgb.head(20)
# Out:
#           Feature  Importance_Mean  Importance_Std
# 13            V19         0.115112        0.003675
# 0              V1         0.052930        0.001351
# 9             V11         0.043762        0.001320
# 7              V9         0.037630        0.000885
# 6              V8         0.034926        0.001876
# 8             V10         0.028270        0.001431
# 4              V6         0.021593        0.000582
# 3              V5         0.020934        0.000844
# 12            V18         0.020224        0.000689
# 5              V7         0.016560        0.000518
# 2              V4         0.012255        0.000582
# 1              V3         0.008021        0.000439
# 10            V15         0.007292        0.000519
# 18    V12_Ausente         0.003091        0.000232
# 40    V17_Premium         0.003052        0.000460
# 37  V17_Economico         0.002472        0.000178
# 30    V14_Inativo         0.002376        0.000211
# ...

# %%
logistic_importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Coefficient": logistic.coef_[0]
})

logistic_importance["Abs_Coefficient"] = (
    logistic_importance["Coefficient"].abs()
)

logistic_importance = logistic_importance.sort_values(
    "Abs_Coefficient",
    ascending=False
)

logistic_importance.head(20)
# Out:
#           Feature  Coefficient  Abs_Coefficient
# 13            V19    -0.535611         0.535611
# 38    V17_Inativo     0.322558         0.322558
# 40    V17_Premium    -0.288979         0.288979
# 8             V10     0.277460         0.277460
# 20    V12_Inativo    -0.275131         0.275131
# 7              V9    -0.246015         0.246015
# 9             V11    -0.223786         0.223786
# 0              V1    -0.197393         0.197393
# 5              V7    -0.171587         0.171587
# 19       V12_Fiel     0.169381         0.169381
# 6              V8    -0.162157         0.162157
# 22  V12_Ocasional     0.154323         0.154323
# 3              V5     0.115714         0.115714
# 4              V6     0.114700         0.114700
# 14           V2_B     0.104609         0.104609
# 25    V13_Inativo     0.087105         0.087105
# 35     V17_Basico    -0.062449         0.062449
# 18    V12_Ausente     0.061192         0.061192
# 34    V17_Ausente     0.061192         0.061192
# ...

# %%
top_lgbm = set(permutation_lgbm.head(20)["Feature"])
top_xgb = set(permutation_xgb.head(20)["Feature"])
top_logistic = set(logistic_importance.head(20)["Feature"])

common_features = sorted(top_lgbm.intersection(top_xgb, top_logistic))

common_features
# Out:
# ['V1',
#  'V10',
#  'V11',
#  'V17_Premium',
#  'V18',
#  'V19',
#  'V2_B',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9']

# %%
selected_features = [
    "V1",
    "V10",
    "V11",
    "V17_Premium",
    "V18",
    "V19",
    "V2_B",
    "V5",
    "V6",
    "V7",
    "V8",
    "V9"
]
X_train_reduced = X_train[selected_features]
X_test_reduced = X_test[selected_features]

# %%
X_train_reduced.shape, X_test_reduced.shape
# Out:
# ((14996, 12), (3749, 12))

# %%
X_train_reduced.head()
# Out:
#                V1  V10  V11  V17_Premium      V18  V19  V2_B           V5  \
# 9582    72.889999   52   53            0  0.00000   42     0     0.000000
# 5023   152.542343    5  181            1  0.52727   66     0   786.909973
# 1513   302.121552    2  353            1  0.75843   52     0  2039.550049
# 14654  192.400375    0  301            1  0.42789   36     1  1818.560059
# 17798   95.746002   15  402            0  0.50887   50     0   688.669983
#
#             V6           V7       V8       V9
# 9582   0.00000     0.000000  0.02437  0.10481
# 5023   2.72000   414.915192  0.02437 -0.04361
# 1513   5.12000  1546.862427  0.02325 -0.01642
# 14654  4.04444   778.152649  0.18852  0.26654
# 17798  3.66013   350.442871  0.02437 -0.05505

# %%
scaler_reduced = StandardScaler()

X_train_reduced_scaled = scaler_reduced.fit_transform(
    X_train_reduced
)

X_test_reduced_scaled = scaler_reduced.transform(
    X_test_reduced
)

# %%
logistic_reduced = LogisticRegression(
    class_weight="balanced",
    max_iter=1000,
    random_state=42
)

logistic_reduced.fit(
    X_train_reduced_scaled,
    y_train
)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
xgb_reduced = XGBClassifier(
    n_estimators=300,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42,
    n_jobs=-1
)

xgb_reduced.fit(
    X_train_reduced,
    y_train
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
lgbm_reduced = LGBMClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

lgbm_reduced.fit(
    X_train_reduced,
    y_train
)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.8,
#                learning_rate=0.05, n_estimators=300, n_jobs=-1, random_state=42,
#                subsample=0.8, verbosity=-1)

# %%
y_pred_logistic_reduced = logistic_reduced.predict(
    X_test_reduced_scaled
)

y_prob_logistic_reduced = logistic_reduced.predict_proba(
    X_test_reduced_scaled
)[:, 1]

y_pred_xgb_reduced = xgb_reduced.predict(
    X_test_reduced
)

y_prob_xgb_reduced = xgb_reduced.predict_proba(
    X_test_reduced
)[:, 1]

y_pred_lgbm_reduced = lgbm_reduced.predict(
    X_test_reduced
)

y_prob_lgbm_reduced = lgbm_reduced.predict_proba(
    X_test_reduced
)[:, 1]

# %%
reduced_results = []

reduced_models = {
    "Logistic Regression": (
        y_pred_logistic_reduced,
        y_prob_logistic_reduced
    ),
    "XGBoost": (
        y_pred_xgb_reduced,
        y_prob_xgb_reduced
    ),
    "LightGBM": (
        y_pred_lgbm_reduced,
        y_prob_lgbm_reduced
    )
}

# %%
for name, (y_pred, y_prob) in reduced_models.items():

    metrics = evaluate_model(
        y_test,
        y_pred,
        y_prob
    )

    metrics["Modelo"] = name

    reduced_results.append(metrics)

# %%
reduced_results_df = pd.DataFrame(reduced_results)

reduced_results_df["KS"] = reduced_results_df["Modelo"].map({
    "Logistic Regression": calculate_ks(
        y_test,
        y_prob_logistic_reduced
    ),
    "XGBoost": calculate_ks(
        y_test,
        y_prob_xgb_reduced
    ),
    "LightGBM": calculate_ks(
        y_test,
        y_prob_lgbm_reduced
    )
})

reduced_results_df = reduced_results_df[
    [
        "Modelo",
        "Accuracy",
        "Precision",
        "Recall",
        "F1",
        "AUC",
        "Gini",
        "KS"
    ]
]

reduced_results_df.sort_values(
    "AUC",
    ascending=False
)
# Out:
#                 Modelo  Accuracy  Precision    Recall        F1       AUC  \
# 1              XGBoost  0.805281   0.557692  0.116310  0.192478  0.711885
# 0  Logistic Regression  0.646306   0.314744  0.656417  0.425477  0.706574
# 2             LightGBM  0.698853   0.349407  0.590909  0.439146  0.704781
#
#        Gini        KS
# 1  0.423771  0.314603
# 0  0.413147  0.312628
# 2  0.409563  0.329538

# %%
from sklearn.metrics import (
    precision_score,
    recall_score,
    f1_score,
    accuracy_score
)

thresholds = np.arange(0.10, 0.56, 0.05)

threshold_results = []

for threshold in thresholds:

    y_pred_threshold = (
        y_prob_lgbm_reduced >= threshold
    ).astype(int)

    threshold_results.append({
        "Threshold": threshold,
        "Accuracy": accuracy_score(
            y_test,
            y_pred_threshold
        ),
        "Precision": precision_score(
            y_test,
            y_pred_threshold
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold
        )
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#    Threshold  Accuracy  Precision    Recall        F1
# 0       0.10  0.281942   0.213612  0.969251  0.350072
# 1       0.15  0.350760   0.226831  0.935829  0.365154
# 2       0.20  0.409976   0.239872  0.902406  0.379001
# 3       0.25  0.462790   0.250394  0.848930  0.386724
# 4       0.30  0.512403   0.263365  0.803476  0.396700
# 5       0.35  0.566818   0.282738  0.762032  0.412446
# 6       0.40  0.610830   0.299718  0.711230  0.421720
# 7       0.45  0.656975   0.326227  0.675134  0.439895
# 8       0.50  0.698853   0.349407  0.590909  0.439146
# 9       0.55  0.729795   0.369971  0.504011  0.426712

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["F1"],
    marker="o",
    label="F1"
)

plt.xlabel("Threshold")
plt.ylabel("Métrica")
plt.title("Precision, Recall e F1 por Threshold - LightGBM")
plt.legend()
plt.grid()

plt.show()

# %%
thresholds = np.arange(0.10, 0.56, 0.05)

threshold_results = []

for threshold in thresholds:

    y_pred_threshold = (
        y_prob_xgb_reduced >= threshold
    ).astype(int)

    threshold_results.append({
        "Threshold": threshold,
        "Accuracy": accuracy_score(
            y_test,
            y_pred_threshold
        ),
        "Precision": precision_score(
            y_test,
            y_pred_threshold
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold
        )
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#    Threshold  Accuracy  Precision    Recall        F1
# 0       0.10  0.460656   0.254054  0.879679  0.394248
# 1       0.15  0.576154   0.286873  0.756684  0.416024
# 2       0.20  0.662043   0.324544  0.641711  0.431073
# 3       0.25  0.723660   0.366913  0.530749  0.433880
# 4       0.30  0.754068   0.391791  0.421123  0.405928
# 5       0.35  0.777274   0.425894  0.334225  0.374532
# 6       0.40  0.792478   0.463235  0.252674  0.326990
# 7       0.45  0.798346   0.483740  0.159091  0.239437
# 8       0.50  0.805281   0.557692  0.116310  0.192478
# 9       0.55  0.803948   0.582278  0.061497  0.111245

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["F1"],
    marker="o",
    label="F1"
)

plt.xlabel("Threshold")
plt.ylabel("Métrica")
plt.title("Precision, Recall e F1 por Threshold - XGBoost")
plt.legend()
plt.grid()

plt.show()

# %%
thresholds = np.arange(0.10, 0.56, 0.05)

threshold_results = []

for threshold in thresholds:

    y_pred_threshold = (
        y_prob_logistic_reduced >= threshold
    ).astype(int)

    threshold_results.append({
        "Threshold": threshold,
        "Accuracy": accuracy_score(
            y_test,
            y_pred_threshold
        ),
        "Precision": precision_score(
            y_test,
            y_pred_threshold
        ),
        "Recall": recall_score(
            y_test,
            y_pred_threshold
        ),
        "F1": f1_score(
            y_test,
            y_pred_threshold
        )
    })

threshold_df = pd.DataFrame(threshold_results)

threshold_df
# Out:
#    Threshold  Accuracy  Precision    Recall        F1
# 0       0.10  0.204321   0.200161  0.997326  0.333408
# 1       0.15  0.231795   0.205362  0.993316  0.340357
# 2       0.20  0.278741   0.214536  0.982620  0.352180
# 3       0.25  0.338224   0.226397  0.958556  0.366284
# 4       0.30  0.400907   0.239750  0.922460  0.380585
# 5       0.35  0.471859   0.258052  0.878342  0.398907
# 6       0.40  0.536943   0.276268  0.815508  0.412720
# 7       0.45  0.596426   0.296434  0.744652  0.424058
# 8       0.50  0.646306   0.314744  0.656417  0.425477
# 9       0.55  0.694585   0.340562  0.566845  0.425489

# %%
plt.figure(figsize=(10, 6))

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Precision"],
    marker="o",
    label="Precision"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["Recall"],
    marker="o",
    label="Recall"
)

plt.plot(
    threshold_df["Threshold"],
    threshold_df["F1"],
    marker="o",
    label="F1"
)

plt.xlabel("Threshold")
plt.ylabel("Métrica")
plt.title("Precision, Recall e F1 por Threshold - Logistic Regression")
plt.legend()
plt.grid()

plt.show()

# %%
X_final = df[selected_features]
y_final = df["PERFORMANCE (var resposta)"]

lgbm_final = LGBMClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=-1,
    num_leaves=31,
    subsample=0.8,
    colsample_bytree=0.8,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1,
    verbosity=-1
)

lgbm_final.fit(
    X_final,
    y_final
)
# Out:
# LGBMClassifier(class_weight='balanced', colsample_bytree=0.8,
#                learning_rate=0.05, n_estimators=300, n_jobs=-1, random_state=42,
#                subsample=0.8, verbosity=-1)

# %%
import joblib

joblib.dump(
    lgbm_final,
    "../models/lightgbm_final.pkl"
)

joblib.dump(
    selected_features,
    "../models/selected_features.pkl"
)
# Out:
# ['../models/selected_features.pkl']
